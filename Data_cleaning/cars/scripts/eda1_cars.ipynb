# %%
from Data_cleaning.cars.data import __path__ as datapath
import os
import sys

import pandas as pd

from Data_cleaning.cars.scripts.utils import *

# %%
src_path = datapath._path[0]
print(src_path)

src_file = os.path.join(src_path,'Car_Models.csv')

df_raw = pd.read_csv(src_file)
# Out:
# d:\data\officeworkspace-20191016t044923z-001\officeworkspace\python_challenges\Data_cleaning\cars\data

# %%
df_raw.head()
df_raw.size
df_raw.columns
# Out:
# Index(['Company', 'Model', 'Horsepower', 'Torque', 'Transmission Type',
#        'Drivetrain', 'Fuel Economy', 'Number of Doors', 'Price',
#        'Model Year Range', 'Body Type', 'Engine Type', 'Number of Cylinders'],
#       dtype='object')

# %%
suvs = df_raw[df_raw['Body Type']=='SUV']

# %%
suvs
# Out:
#          Company       Model                        Horsepower
# 10      Mahindra      XUV300                            109 hp  \
# 11      Mahindra     Scorpio                            140 hp
# 12      Mahindra        Thar  152 hp (petrol), 132 hp (diesel)
# 13      Mahindra      Bolero                             75 hp
# 15      Mahindra  Alturas G4                            178 hp
# ..           ...         ...                               ...
# 396  Tata Motors       Punch                            85 bhp
# 397  Tata Motors       Nexon                           108 bhp
# 398  Tata Motors     Harrier                           170 bhp
# 399  Tata Motors      Safari                           170 bhp
# 403  Tata Motors        Thar                117 bhp @ 3500 rpm
#
#                                Torque                  Transmission Type
# 10                             200 Nm        6-speed Manual, 6-speed AMT  \
# 11                             320 Nm                     6-speed Manual
# 12   320 Nm (petrol), 300 Nm (diesel)         6-speed Manual, 6-speed AT
# 13                             210 Nm                     5-speed Manual
# 15                             420 Nm                  7-speed Automatic
# ..                                ...                                ...
# 396                            113 Nm                     5-speed manual
# 397                            170 Nm                6-speed manual, AMT
# 398                            350 Nm  6-speed manual, 6-speed automatic
# 399                            350 Nm  6-speed manual, 6-speed automatic
# 403            250 Nm @ 1500-2000 rpm  5-speed manual, 6-speed automatic
#
#                             Drivetrain         Fuel Economy Number of Doors
# 10                                 FWD           13-20 km/l               5  \
# 11                                 RWD              15 km/l            5, 7
# 12                                 4WD            7-12 km/l            4, 6
# 13                                 RWD              16 km/l            5, 7
# 15                                 AWD              12 km/l               5
# ..                                 ...                  ...             ...
# 396                  Front-wheel drive           19.84 kmpl               5
# 397                  Front-wheel drive            20.5 kmpl               5
# 398                    All-wheel drive            13.1 kmpl               5
# 399                    All-wheel drive            12.7 kmpl               7
# 403  Rear-wheel drive, all-wheel drive  15.2 kmpl / 18 kmpl               5
#
#                          Price Model Year Range Body Type
# 10       Rs. 7.96 - 13.33 Lakh   2019 - present       SUV  \
# 11      Rs. 12.57 - 16.53 Lakh   2020 - present       SUV
# 12      Rs. 12.11 - 16.86 Lakh   2020 - present       SUV
# 13        Rs. 8.67 - 9.39 Lakh   2001 - present       SUV
# 15      Rs. 28.74 - 31.73 Lakh   2018 - present       SUV
# ..                         ...              ...       ...
# 396                 4.59 lakhs     2020-present       SUV
# 397                 6.49 lakhs     2017-present       SUV
# 398                14.69 lakhs     2019-present       SUV
# 399                24.69 lakhs     2021-present       SUV
# 403  ₹10.55 Lakh - ₹16.78 Lakh     2020-present       SUV
#
#                                            Engine Type Number of Cylinders
# 10                1.2L Turbo Petrol, 1.5L Turbo Diesel                 3/4
# 11                                   2.2L mHawk Diesel                   4
# 12                2.0L Turbo Petrol, 2.2L mHawk Diesel                   4
# 13                                 1.5L mHawk75 Diesel                   3
# 15                                   2.2L mHawk Diesel                   4
# ..                                                 ...                 ...
# 396                    1.2L naturally aspirated petrol                   3
# 397  1.2L turbocharged petrol, 1.5L turbocharged di...                3, 4
# 398                           2.0L turbocharged petrol                   4
# 399                           2.0L turbocharged petrol                   4
# 403                           2.0L turbocharged diesel                   4
#
# [135 rows x 13 columns]

# %% [markdown]
# # methods needed
#     uniformize data
#         - make everythign lowercase
#     add a column
#         - market
#     convert price to usd
#     convert price to any user given
#         add as extra column
#     convert mileage to
#         mpg,
#         kms/l,
#         l/100 kms
#     convert horsepower
#         hp
#         assign lower limit higher limit
#     convert torgue
#         hp
#         assign lower limit higher limit

# %%
df = df_raw.copy()

# %% [markdown]
# add market column

# %%
market_mapping_dict = {
    'APAC': ['rs','lakh'],
    'NAM' : ['$',],
}

# %%
df['market'] = df.Price.apply(get_market,args=[market_mapping_dict])
